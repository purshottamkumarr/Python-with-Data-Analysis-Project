# %% [markdown]
# <a href="https://colab.research.google.com/github/purshottamkumarr/Python-with-Data-Analysis-Project/blob/main/Covid_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/Covid Pandas.csv")

# %%
data.head(5)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.shape
# Out:
# (321, 6)

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Show the No of death,confirmed,and Recovered Cases in Each Region.

# %%
data.head(5)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.groupby("Region").sum().head(10)
# Out:
#                                                                   Date  \
# Region
# Afghanistan                                                  4/29/2020
# Albania                                                      4/29/2020
# Algeria                                                      4/29/2020
# Andorra                                                      4/29/2020
# Angola                                                       4/29/2020
# Antigua and Barbuda                                          4/29/2020
# Argentina                                                    4/29/2020
# Armenia                                                      4/29/2020
# Australia            4/29/20204/29/20204/29/20204/29/20204/29/20204...
# Austria                                                      4/29/2020
#
#                                                                  State  \
# Region
# Afghanistan                                                          0
# ...

# %%
data.groupby("Region")["Confirmed"].sum().sort_values(ascending = False).head(5)
# Out:
# Region
# US        1039909
# Spain      236899
# Italy      203591
# France     166543
# UK         166441
# Name: Confirmed, dtype: int64

# %%
data.groupby("Region")[["Confirmed","Recovered"]].sum()
# Out:
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %% [markdown]
# Remove all the Records where Confirmed Cases is less than 10

# %%
data[~(data["Confirmed"]<10)]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
data.head(10)
# Out:
#         Date State               Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN          Afghanistan       1939      60        252
# 1  4/29/2020   NaN              Albania        766      30        455
# 2  4/29/2020   NaN              Algeria       3848     444       1702
# 3  4/29/2020   NaN              Andorra        743      42        423
# 4  4/29/2020   NaN               Angola         27       2          7
# 5  4/29/2020   NaN  Antigua and Barbuda         24       3         11
# 6  4/29/2020   NaN            Argentina       4285     214       1192
# 7  4/29/2020   NaN              Armenia       1932      30        900
# 8  4/29/2020   NaN              Austria      15402     580      12779
# 9  4/29/2020   NaN           Azerbaijan       1766      23       1267

# %% [markdown]
# In which Region Maxium No of Confirmed cases are Record?

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby("Region")["Confirmed"].sum().sort_values(ascending = True).head(2)
# Out:
# Region
# Yemen             6
# Western Sahara    6
# Name: Confirmed, dtype: int64

# %% [markdown]
# In which Region Minium No the Death Ceases are Record?

# %%
data.groupby("Region")["Deaths"].sum().sort_values(ascending = True).head(10)
# Out:
# Region
# Laos                0
# Mongolia            0
# Mozambique          0
# Cambodia            0
# Fiji                0
# Namibia             0
# Nepal               0
# Madagascar          0
# Macau               0
# Papua New Guinea    0
# Name: Deaths, dtype: int64

# %% [markdown]
# How Many Confirmed,Death,Recovered Cases were Reported From India till 29 April 2020

# %%
data[data["Region"] == "India"]
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
data[data.Region =="India"]
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# Sort the Entire Data wrt to No Of Death Cases In Asending order ?

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.sort_values(by=["Deaths"],ascending = True)
# Out:
#           Date                  State            Region  Confirmed  Deaths  \
# 126  4/29/2020                    NaN  Papua New Guinea          8       0
# 279  4/29/2020   Prince Edward Island            Canada         27       0
# 135  4/29/2020                    NaN            Rwanda        225       0
# 272  4/29/2020  Northwest Territories            Canada          5       0
# 271  4/29/2020     Northern Territory         Australia         28       0
# ..         ...                    ...               ...        ...     ...
# 265  4/29/2020               New York                US     299691   23477
# 57   4/29/2020                    NaN            France     165093   24087
# 153  4/29/2020                    NaN             Spain     236899   24275
# 168  4/29/2020                    NaN                UK     165221   26097
# 80   4/29/2020                    NaN             Italy     203591   27682
#
#      Recovered
# 126          0
# 279          0
# 135         98
# ...

# %% [markdown]
# Sort the Entire Data wrt to No Of Confirmed Cases In Asending order ?

# %%
data.sort_values(by =["Confirmed"],ascending = True).head(10)
# Out:
#           Date                             State          Region  Confirmed  \
# 285  4/29/2020                         Recovered              US          0
# 284  4/29/2020                         Recovered          Canada          0
# 203  4/29/2020      Diamond Princess cruise ship          Canada          0
# 305  4/29/2020                             Tibet  Mainland China          1
# 289  4/29/2020         Saint Pierre and Miquelon          France          1
# 184  4/29/2020                          Anguilla              UK          3
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba     Netherlands          5
# 272  4/29/2020             Northwest Territories          Canada          5
# 288  4/29/2020                  Saint Barthelemy          France          6
# 178  4/29/2020                               NaN           Yemen          6
#
#      Deaths  Recovered
# 285       0     120720
# 284       0      20327
# 203       1          0
# 305       0          1
# ...

# %% [markdown]
# Sort the Entire Data wrt to No Of Recovered  Cases In Asending order ?

# %%
data.sort_values(by = ["Recovered"],ascending = True).head(10)
# Out:
#           Date                 State            Region  Confirmed  Deaths  \
# 240  4/29/2020                Kansas                US       3839     134
# 279  4/29/2020  Prince Edward Island            Canada         27       0
# 251  4/29/2020              Michigan                US      40399    3670
# 193  4/29/2020      British Columbia            Canada       2087     109
# 280  4/29/2020           Puerto Rico                US       1433      86
# 213  4/29/2020               Georgia                US      25775    1101
# 249  4/29/2020         Massachusetts                US      60265    3405
# 199  4/29/2020              Colorado                US      14758     766
# 126  4/29/2020                   NaN  Papua New Guinea          8       0
# 252  4/29/2020             Minnesota                US       4644     319
#
#      Recovered
# 240          0
# 279          0
# 251          0
# 193          0
# 280          0
# 213          0
# 249          0
# 199          0
# ...
